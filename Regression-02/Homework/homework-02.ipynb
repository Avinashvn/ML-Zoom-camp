# %%
import pandas as pd
import numpy as np

url = "https://raw.githubusercontent.com/alexeygrigorev/datasets/master/car_fuel_efficiency.csv"

df = pd.read_csv(url)

df.head(20)
# Out:
#     engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                   170            3.0       159.0     3413.433759
# 1                   130            5.0        97.0     3149.664934
# 2                   170            NaN        78.0     3079.038997
# 3                   220            4.0         NaN     2542.392402
# 4                   210            1.0       140.0     3460.870990
# 5                   190            3.0         NaN     2484.883986
# 6                   240            7.0       127.0     3006.542287
# 7                   150            4.0       239.0     3638.657780
# 8                   250            1.0       174.0     2714.219310
# 9                   150            4.0       123.0     3509.036569
# 10                  230            5.0       100.0     3111.810181
# 11                  150            5.0         NaN     1967.200421
# 12                  320            5.0       145.0     2783.868974
# ...

# %%
selected_data = df[['engine_displacement','horsepower','vehicle_weight','model_year','fuel_efficiency_mpg']]

# %%
selected_data.head(8)
# Out:
#    engine_displacement  horsepower  vehicle_weight  model_year  \
# 0                  170       159.0     3413.433759        2003
# 1                  130        97.0     3149.664934        2007
# 2                  170        78.0     3079.038997        2018
# 3                  220         NaN     2542.392402        2009
# 4                  210       140.0     3460.870990        2009
# 5                  190         NaN     2484.883986        2008
# 6                  240       127.0     3006.542287        2012
# 7                  150       239.0     3638.657780        2020
#
#    fuel_efficiency_mpg
# 0            13.231729
# 1            13.688217
# 2            14.246341
# 3            16.912736
# 4            12.488369
# 5            17.271818
# 6            13.210412
# 7            12.848884
